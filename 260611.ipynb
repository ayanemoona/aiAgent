# %%
import openai

client = openai.OpenAI()

messages = []

# %%
def get_weather(city):
    return '33degrees and celsius'

FUNCTION_MAP ={
    'get_weather': get_weather
}

# %%
TOOLS = [
    {
        "type" : "function",
        "function" : {
            "name" : "get_weather",
            "description" : "A function to get the weather of a City",
            "parameters" : {
                "type" : "object",
                "properties" : {
                    "city" : {
                        "type" : "string",
                        "description" : "The name of the city to get the weather of."
                    }
                },
                "requeired" : ["city"]
            }   
        }
    }
]

# %%
def call_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
        tools=TOOLS
    ) 
    print(response)
    massage = response.choices[0].message.content
    messages.append({"role": "assistant", "content": massage})
    print(f"AI: {massage}")

# %%
while True:
    message = input("Send a message to the LLM ...")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({
            "role": "user",
            "content": message
        })
        print(f"User: {message}")
        call_ai()
# Out:
# User: my name is moona
# ChatCompletion(id='chatcmpl-DpWMXTWfYOY0IMk2Oo846pcsljPUI', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Hello Moona! How can I assist you today?', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1781171501, model='gpt-4o-mini-2024-07-18', object='chat.completion', moderation=None, service_tier='default', system_fingerprint='fp_6c2953e649', usage=CompletionUsage(completion_tokens=12, prompt_tokens=64, total_tokens=76, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# AI: Hello Moona! How can I assist you today?
# User: what is the weather in Spain
# ChatCompletion(id='chatcmpl-DpWMz6ZVvBauqhdGQ6mrs0ti1kNmL', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_2MT2vRCYAllOQ8OITdmNO13u', function=Function(arguments='{"city":"Spain"}', name='get_weather'), type='function')]))], created=1781171529, model='gpt-4o-mini-2024-07-18', object='chat.completion', moderation=None, service_tier='default', system_fingerprint='fp_6c2953e649', usage=CompletionUsage(completion_tokens=14, prompt_tokens=89, total_tokens=103, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# AI: None
