# %%
import openai

client = openai.OpenAI()

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "Hello my name is moona"
        }
    ]
)
print(response.choices[0].message.content)
# Out:
# Hello Moona! How can I assist you today?

# %%
import openai

client = openai.OpenAI()

messages = []

# %%
def call_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages
    ) 
    massage = response.choices[0].message.content
    messages.append({"role": "assistant", "content": massage})
    print(f"AI: {massage}")

# %%
while True:
    message = input("Send a message to the LLM ...")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({
            "role": "user",
            "content": message
        })
        print(f"User: {message}")
        call_ai()
# Out:
# User: my name is moona
# AI: Nice to meet you, Moona! How can I assist you today?
# User: what is my name
# AI: Your name is Moona. How can I help you today?
# User: I'm from Korea
# AI: That's great to hear, Moona! Korea has a rich culture and history. Is there something specific you’d like to talk about related to Korea, or any questions you have?
# User: What was the first question I asked you?
# AI: You asked, "what is my name."
# User: What is the closest island country to where i was born?
# AI: To provide an accurate answer, I would need to know the specific location in Korea where you were born. However, generally speaking, some of the closest island countries to the Korean Peninsula include Japan (specifically the islands of Tsushima and Shikoku) and, further southeast, the Philippines. If you can specify your birthplace, I can give a more precise answer!

# %%
import openai

client = openai.OpenAI()

messages = []

# %%
def call_ai_self():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages
    )
    answer = response.choices[0].message.content
    messages.append({
        "role": "assistant",
        "content": answer
    })
    print(f"AI: {answer}")

# %%
while True:
    message = input("Send a message to the LLM ...")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({
            "role": "user",
            "content": message
        })
        print(f"User: {message}")
        call_ai_self()
# Out:
# User: 나는 SF 영화를 좋아해
# AI: SF 영화는 정말 매력적인 장르죠! 미래의 기술, 외계 생명체, 그리고 다양한 상상력을 자극하는 이야기들이 가득하니까요. 어떤 SF 영화가 가장 마음에 드세요? 또는 추천받고 싶은 영화가 있나요?
# User: 인셉션이랑 인터스텔라는 이미 봤어
# AI: 두 영화 모두 크리스토퍼 놀란 감독의 작품으로, 깊이 있는 스토리와 뛰어난 비주얼이 특징이죠. 인셉션은 꿈의 세계와 심리를 탐구하고, 인터스텔라는 우주 여행과 사랑에 대한 메시지를 담고 있어요.
#
# 그렇다면 이런 영화들이 마음에 드셨다면, **"블레이드 러너 2049"**나 **"히든 피겨스"**를 추천해 드릴 수 있을 것 같아요. 또는 **"엑스 마키나"**처럼 인공지능에 대한 깊이 있는 이야기도 흥미롭고요. 어떤 스타일의 영화를 더 좋아하시나요?
# User: 오늘 밤에 뭐 볼지 추천해 줄래?
# AI: 물론이죠! 오늘 밤에 보기 좋은 SF 영화를 몇 가지 추천해 드릴게요:
#
# 1. **"블레이드 러너 2049"** - 미래의 세계에서 인공지능과 인간의 경계를 탐색하는 이야기로, 시각적으로도 매우 아름답습니다.
#
# 2. **"엑스 마키나"** - 인공지능과 인간의 관계에 대한 심리적인 스릴러로, 짧은 시간 안에 깊이 있는 질문을 던집니다.
#
# 3. **"소스 코드"** - 주인공이 반복되는 시간 속에서 테러를 막기 위해 노력하는 흥미로운 이야기입니다. 반전도 많아요!
#
# 4. **"마션"** - 화성에 홀로 남겨진 우주 비행사의 생존기를 다룬 영화로, 과학적 요소와 감동적인 스토리가 잘 어우러져 있습니다.
#
# 5. **"테넷"** - 시간의 흐름을 뒤바꾸는 독특한 설정으로, 놀란 특유의 복잡한 이야기 구조가 매력적입니다.
#
# 어떤 영화가 가장 끌리시나요?
# User: 내가 좋아하는 장르랑 이미 본 영화가 뭐라고 했지?
# AI: 당신은 SF 영화를 좋아하시고, 이미 **"인셉션"**과 **"인터스텔라"**를 보셨다고 말씀하셨습니다. 이 두 영화가 흥미로운 심리적 요소와 복잡한 서사를 다루고 있기 때문에, 비슷한 스타일의 영화 추천을 드렸습니다. 추가로 궁금한 점이나 다른 요청이 있으면 말씀해 주세요!
